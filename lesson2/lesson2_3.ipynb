# %%
print(5 + 8)
print(90 - 10)
print(4 * 7)
print(7 / 2)
print(7 // 2)
print(7 % 3)
print(3 ** 4)
print(99 ** 99)
# Out:
# 13
# 80
# 28
# 3.5
# 3
# 1
# 81

# %%
# python的基本資料型別
# int
5
15

# float
5.0

# str
"5"
'5'

# bool
True
False

5 + 5

5 + 5.0

5 + int('5')
# Out:
# 10
