# %%
chinese = 78
chinese = chinese + 5
english = 92
math = 67

total = chinese + english + math

# %%
chinese = 78
chinese = chinese + 5
english = 92
math = 67

total = chinese + english + math

average = total / 3
average
